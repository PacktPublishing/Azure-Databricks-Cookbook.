# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("api_key", "", "API Key")

# %%
choices = ["Red", "Green", "Blue"]

dbutils.widgets.dropdown("background_color", "Red", choices, "Background Color")

# %%
choices = ["Red", "Green", "Blue"]

dbutils.widgets.combobox("background_color", "Red", choices, "Background Color")

# %%
choices = ["Red", "Green", "Blue"]

dbutils.widgets.multiselect("background_color", "Red", choices, "Background Color")
