# %%
dbutils.library.help("list")

# %%
dbutils.library.list()

# %%
dbutils.library.installPyPI("wasabi")

# %%
dbutils.library.list()

# %%
# %sh /databricks/python/bin/pip list

# %%
# %r
installed.packages()
