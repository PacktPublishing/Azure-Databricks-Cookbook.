# %%
dbutils.widgets.text("text_box1", "", "Text")
dbutils.widgets.text("text_box2", "", "Text")
dbutils.widgets.text("text_box3", "", "Text")
dbutils.widgets.text("text_box4", "", "Text")
dbutils.widgets.text("text_box5", "", "Text")

# %%
dbutils.widgets.removeAll()

# %%
dbutils.widgets.remove("text_box")
