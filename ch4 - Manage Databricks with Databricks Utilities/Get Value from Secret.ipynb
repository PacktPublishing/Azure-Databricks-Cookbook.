# %%
dbutils.secrets.help()

# %%
dbutils.secrets.get("Azure", "StorageKey")

# %%
dbutils.secrets.getBytes("Azure", "StorageKey")

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("Azure")
