# %%
display(dbutils.fs.ls("/databricks-datasets"))

# %%
display(dbutils.fs.ls("/databricks-datasets/adult"))

# %%
dbutils.fs.head("/databricks-datasets/adult/adult.data")

# %%
dbutils.fs.head("/databricks-datasets/adult/README.md")

# %%
dbutils.fs.head("/databricks-datasets/adult/README.md", 500)

# %%
dbutils.fs.help("head")
