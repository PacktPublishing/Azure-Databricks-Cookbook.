# %%
from graphframes.examples import Graphs
from pyspark.sql.functions import desc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
graph = Graphs(sqlContext).friends()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-4309631684153396&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>graph <span class="ansiyellow">=</span> Graphs<span class="ansiyellow">(</span>sqlContext<span class="ansiyellow">)</span><span class="ansiyellow">.</span>gridIsingModel<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">TypeError</span>: gridIsingModel() missing 1 required positional argument: &apos;n&apos;</div>

# %%
top_edge = graph \
  .edges \
  .groupBy("src", "dst") \
  .count() \
  .orderBy(desc("count")) \
  .limit(10) 

display(top_edge)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dst</th><th>count</th></tr></thead><tbody><tr><td>e</td><td>d</td><td>1</td></tr><tr><td>e</td><td>f</td><td>1</td></tr><tr><td>b</td><td>c</td><td>1</td></tr><tr><td>d</td><td>a</td><td>1</td></tr><tr><td>f</td><td>c</td><td>1</td></tr><tr><td>a</td><td>b</td><td>1</td></tr><tr><td>c</td><td>b</td><td>1</td></tr></tbody></table></div>
