# %%
from graphframes.examples import Graphs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
graph = Graphs(sqlContext).friends()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
page_rank = graph.pageRank(resetProbability=0.15, tol=0.1)
display(page_rank.vertices)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>pagerank</th></tr></thead><tbody><tr><td>b</td><td>Bob</td><td>36</td><td>2.4954298786231983</td></tr><tr><td>e</td><td>Esther</td><td>32</td><td>0.21274135293601043</td></tr><tr><td>a</td><td>Alice</td><td>34</td><td>0.3935715029316193</td></tr><tr><td>f</td><td>Fanny</td><td>36</td><td>0.30315642793381486</td></tr><tr><td>d</td><td>David</td><td>29</td><td>0.30315642793381486</td></tr><tr><td>c</td><td>Charlie</td><td>30</td><td>2.2919444096415424</td></tr></tbody></table></div>
