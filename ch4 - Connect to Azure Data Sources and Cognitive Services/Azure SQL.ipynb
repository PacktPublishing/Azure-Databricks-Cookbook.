# %%
dbPassword = "<Azure SQL password>"

connectionString = "jdbc:sqlserver://demodatawarehouse.database.windows.net:1433;database=<databaseName>;user=<username>;password={0};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;".format(dbPassword)

# %%
df = spark.read.jdbc(connectionString, "<Table name>")

# %%
display(df)

# %%
new_df = spark.read.format("jdbc") \
  .option("url", connectionString) \
  .option("dbtable", "BankData") \
  .load()

# %%
display(new_df)
